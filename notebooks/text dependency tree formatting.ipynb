# %%
# import speech raw text
from cltk import NLP
cltk_nlp = NLP(language="lat")
# Removing ``LatinLexiconProcess`` for this demo b/c it is slow (adds ~9 mins total)
cltk_nlp.pipeline.processes.pop(-1)
print(cltk_nlp.pipeline.processes)
# Now execute NLP algorithms upon input text
# Takes a while
# %time adamofbremen_doc = cltk_nlp.analyze(text="Praeterea unam adhuc insulam recitavit a multis in eo repertam oceano, quae dicitur Winland, eo quod ibi vites sponte nascantur, vinum optimum ferentes. Nam et fruges ibi non seminatas habundare non fabusa opinione, sed certa comperimus relatione Danorum. Item nobis retulit beatae memoriae pontifex Adalbertus in diebus antedecessoris sui quosdam nobiles de Fresia viros causa pervagandi maris in boream vela tetendisse, eo quod ab incolis eius populi dicitur ab ostio Wirrahae fluminis directo cursu in aquilonem nullam terram occurrere preter infinitum occeanum. Cuius rei novitate pervestiganda coniurati sodales a littore Fresonum laeto celeumate progressi sunt. Deinde relinquentes hinc Daniam, inde Britanniam pervenerunt ad Orchadas. Quibus a laeva dimissis, cum Nortmanniam in dextris haberent, longo traiectu glacialem Island collegerunt. A quo loco maria sulcantes in ultimam septentrionis axem, postquam retro se omnes, de quibus supra dictum est, insulas viderunt, omnipotenti Deo et sancto confessori Willehado suam commendantes viam et audatiam subito collapsi sunt in illam tenebrosam rigentis oceani caliginem, quae vix oculis penetrari valeret. Et ecce instabilis oceani euripus ad initia quaedam fontis sui archana recurrens infelices nautas iam desperatos, immo de morte sola cogitantes vehementissimo impetu traxit ad chaos [-hanc dicunt esse voraginem abyssi-] illud profundum, in quo fama est omnes recursus maris, qui decrescere videntur, absorberi et denuo revomi, quod fluctuatio crescens dici solet. Tunc illis solam Dei misericordiam implorantibus, ut animas eorum susciperet, impetus ille recurrens pelagi quasdam sociorum naves abripuit, ceteras autem revomens excursio longe ab alteris post terga repulit. Ita illi ab instanti periculo quod oculis viderant, oportuno Dei auxilio liberati toto nisu remorum fluctus adiuvarunt. Et iam periculum caliginis et provintiam frigoris evadentes, insperate appulerunt ad quandam insulam altissimis in circuitu scopulis ritu oppidi munitam. Huc visendorum gratia locorum egressi reppererunt homines in antris subterraneis meridiano tempore latitantes. Pro quorum foribus infinita iacebat copia vasorum aureorum et eiusmodi metallorum, quae rara mortalibus et preciosa putantur. Itaque sumpta parte gazarum, quam sublevare poterant, laeti remiges festine remeant ad naves. Cum subito retro se venientes contemplati sunt homines mirae altitudinis, quos nostri appellant Cyclopes. Eos antecedebant canes magnitudinem solitam excedentes eorum quadruped urn, quorum incursu raptus est unus de sociis, et in momento laniatus est coram eis. Reliqui vero suscepti ad naves evaserunt periculum, gygantibus, ut referebant, pene in altum vociferando sequentibus. Tali fortuna comitati Fresones Bremam perveniunt, ubi Alebran do pontifici ex ordine cuncta narrantes pio Christo et confessori eius Willehado reversionis et salutis suae hostias immolarunt.")
# Out:
# ‎𐤀 CLTK version '1.1.6'.
# Pipeline for language 'Latin' (ISO: 'lat'): `LatinNormalizeProcess`, `LatinStanzaProcess`, `LatinEmbeddingsProcess`, `StopsProcess`, `LatinLexiconProcess`.
# [<class 'cltk.alphabet.processes.LatinNormalizeProcess'>, <class 'cltk.dependency.processes.LatinStanzaProcess'>, <class 'cltk.embeddings.processes.LatinEmbeddingsProcess'>, <class 'cltk.stops.processes.StopsProcess'>]
# CPU times: user 41.8 s, sys: 1.32 s, total: 43.1 s
# Wall time: 41.7 s

# %%
from cltk.dependency.tree import DependencyTree
from pprint import pprint

i=4
a_tree = DependencyTree.to_tree(adamofbremen_doc.sentences[i])
print("Original:", adamofbremen_doc.sentences_strings[i])

a_tree.print_tree()
# Out:
# Original: Deinde relinquentes hinc Daniam , inde Britanniam pervenerunt ad Orchadas .
# root | pervenerunt_7/verb
#     └─ advmod | Deinde_0/adverb
#     └─ advcl | relinquentes_1/verb
#         └─ advmod | hinc_2/adverb
#         └─ obj | Daniam_3/noun
#         └─ punct | ,_4/punctuation
#     └─ advmod | inde_5/adverb
#     └─ obj | Britanniam_6/noun
#     └─ obl:arg | Orchadas_9/noun
#         └─ case | ad_8/adposition
#     └─ punct | ._10/punctuation

# %%
from cltk import NLP
cltk_nlp = NLP(language="lat")
# Removing ``LatinLexiconProcess`` for this demo b/c it is slow (adds ~9 mins total)
cltk_nlp.pipeline.processes.pop(-1)
liut = "Alium, quem ipse egit, ludum silentio tegi absurdum esse diiudico. Constantinopolitanum palatium ob imperatoris salutem multorum praesidiis militum custoditur. Custodientibus vero victus censusque cottidanus non parvus inpenditur. Contigit itaque XII post corporis refectionem in ipso diei fervore una in domo quiescere. Mos denique imperatoris erat cunctis quiescentibus totum perreptare palatium. Qui cum eodem die quadam, quo XII memorati loethoeo sese dederant, pervenisset, ligno modico, ut non incallidus, ostii pessulo proiecto ingrediendi sibi aditum praebuit. Undecim vero dormientibus, ut ars artem falleret, duodecimus pervigil stertere ceu dormiens coeperat contractisque in fatiem brachiis totum, quod imperator faceret, diligentissime considerabat. Ingressus igitur imperator, dum obdormire cunctos perspiceret, aureorum numismatorum libram pectori uniuscuiusque apposuit; moxque clam regressus, ostium, ut prius fuerat, clausit. Eo autem hoc egit, quatinus exitati et de lucro gratularentur ac, qualiter hoc accideret, non mediocriter mirarentur. Denique discedente imperatore, qui vigil solus extiterat, surrexit dormientiumque nummos aureos sibi adsumpsit atque reposuit; postea vero quieti sese dedit. Imperator igitur pro hoc ludo sollicitus post-nonam horam XII hos, quos nominavimus, ad se venire praecepit eosque ita convenit: Si forte vestrum quempiam somnii visio deterruit aut hilarem reddidit, ut in medium proferat, mea iubet auctoritas; nec minus etiam, si quid novitatis expergefactus quisquam vidit, ut detegat, imperat. Hi itaque, quemadmodum nihil viderant, nil se vidisse responderant. Magis autem super hoc admirati, conticuere intentique ora tenebant. Sperans igitur imperator hos non rei inscitia, sed calliditate aliqua reticere, succensus est ut qui magis coepitque nonnulla terribilia reticentibus comminari. Quod qui omnium conscius erat ut audivit, huiusmodi humillima et supplic voce imperatorem convenit: φιλάνθρωπε βασιλεῦ, id est, humanissime imperator, hi quid viderint, nescio; ego tamen delectabile, atque utinam quod persaepe mihi contingeret, somnium vidi. Undecim his conservis meis hodie vere, sed non oportune dormientibus visus sum, quasi non dormiens, vigilare. Ecce autem magnitudo imperii tui quasi occulte ostium reserans clanculumque ingressa libram auri adposuit supra pectus omnium nostrum. Cumque imperium tuum quasi repedare sotiosque hac in visione cernerem dormitare, continuo ceu laetus exurgens undecim dormientium aureorum numismatorum libras tuli meoque in marsupio, in quo una erat, apposui, quatinus ob trangressionem decalogi ne solum essent XI, verum ob memoriam apostolorum mea una adhibita essent et ipsae XII.  Visio haec, imperator auguste, bonum sit, usque modo me non deterruit, sed hilarem reddidit. utinam interpretatio alia imperio tuo non place at. Nam et me μάντιν κε ὀνειροπόλον (mantin ke oniropolon); id est divinum et somnii venditorem, esse liquido patet. His auditis magno est imperator cachinno inflatus; verum prudentiam huius atque sollicitudinem plus admiratus protinus infit: Antehac σε οὖτε μαντιν οὖτε ὀνειροπόλον se ute mantin ute oniropolon, te neque divinum neque somnii venditorem esse audivi. Hanc vero rem nunc ita aperte dixti, ut nihil circuitionis usus esses. Sed quia vigilandi facultatem sive auspicandi scientiam habere non posses, nisi divino tibi esset munere datum, seu verum sit, ut speramus, immo credimus, seu falsum, Lukianos, id est sicut Lucianus de quodam dicit, quod dormiens multa reppererit atque a gallo exitatus nihil invenerit, tu tamen quicquid videris, quicquid senseris, quicquid etiam inveneris, tuum sit. His auditis, quanta ceteri sint confusione repleti, quantoque hie sit gaudio plenus, eorum quisque in se personas suscipiens animadvertere poterit."
# %time liut_doc = cltk_nlp.analyze(text=liut)
# Out:
# ‎𐤀 CLTK version '1.1.6'.
# Pipeline for language 'Latin' (ISO: 'lat'): `LatinNormalizeProcess`, `LatinStanzaProcess`, `LatinEmbeddingsProcess`, `StopsProcess`, `LatinLexiconProcess`.
# CPU times: user 22.7 s, sys: 1.53 s, total: 24.2 s
# Wall time: 25.4 s

# %%
len(liut_doc.sentences)
# Out:
# 31

# %%
from cltk.dependency.tree import DependencyTree
from pprint import pprint

for i in range(31):
    a_tree = DependencyTree.to_tree(liut_doc.sentences[i])
    print("Original:", liut_doc.sentences_strings[i])
    a_tree.print_tree()
# Out:
# Original: Alium , quem ipse egit , ludum silentio tegi absurdum esse diiudico .
# root | tegi_8/verb
#     └─ nsubj | ludum_6/noun
#     └─ obl | silentio_7/noun
#     └─ xcomp | diiudico_11/adjective
#         └─ nsubj | Alium_0/pronoun
#             └─ acl:relcl | egit_4/verb
#                 └─ punct | ,_1/punctuation
#                 └─ obj | quem_2/pronoun
#                 └─ nsubj | ipse_3/pronoun
#             └─ punct | ,_5/punctuation
#             └─ punct | ._12/punctuation
#         └─ nsubj | absurdum_9/adjective
#         └─ cop | esse_10/auxiliary
# Original: Constantinopolitanum palatium ob imperatoris salutem multorum praesidiis militum custoditur .
# root | custoditur_8/verb
#     └─ nsubj:pass | palatium_1/noun
#         └─ amod | Constantinopolitanum_0/adjective
#     └─ obl | salutem_4/noun
#         └─ case | ob_2/adposition
#         └─ nmod | imperatoris_3/noun
#     └─ obl | praesidiis_6/noun
#         └─ nmod | multorum_5/adjective
# ...

# %%
input_text = """
Original: Alium , quem ipse egit , ludum silentio tegi absurdum esse diiudico .
root | tegi_8/verb
    └─ nsubj | ludum_6/noun
    └─ obl | silentio_7/noun
    └─ xcomp | diiudico_11/adjective
        └─ nsubj | Alium_0/pronoun
            └─ acl:relcl | egit_4/verb
                └─ punct | ,_1/punctuation
                └─ obj | quem_2/pronoun
                └─ nsubj | ipse_3/pronoun
            └─ punct | ,_5/punctuation
            └─ punct | ._12/punctuation
        └─ nsubj | absurdum_9/adjective
        └─ cop | esse_10/auxiliary
Original: Constantinopolitanum palatium ob imperatoris salutem multorum praesidiis militum custoditur .
root | custoditur_8/verb
    └─ nsubj:pass | palatium_1/noun
        └─ amod | Constantinopolitanum_0/adjective
    └─ obl | salutem_4/noun
        └─ case | ob_2/adposition
        └─ nmod | imperatoris_3/noun
    └─ obl | praesidiis_6/noun
        └─ nmod | multorum_5/adjective
        └─ nmod | militum_7/noun
    └─ punct | ._9/punctuation
Original: Custodientibus vero victus censusque cottidanus non parvus inpenditur .
root | inpenditur_7/verb
    └─ advcl | Custodientibus_0/verb
        └─ conj | victus_2/verb
    └─ cc | vero_1/coordinating_conjunction
    └─ nsubj:pass | cottidanus_4/noun
        └─ det | censusque_3/pronoun
    └─ xcomp:pred | parvus_6/adjective
        └─ advmod | non_5/particle
    └─ punct | ._8/punctuation
Original: Contigit itaque XII post corporis refectionem in ipso diei fervore una in domo quiescere .
root | Contigit_0/verb
    └─ advmod | itaque_1/adverb
    └─ obl | XII_2/numeral
    └─ ccomp | quiescere_13/verb
        └─ obl | refectionem_5/noun
            └─ case | post_3/adposition
            └─ nmod | corporis_4/noun
        └─ obl | diei_8/noun
            └─ case | in_6/adposition
            └─ det | ipso_7/determiner
        └─ obl | fervore_9/noun
            └─ nummod | una_10/numeral
        └─ obl | domo_12/noun
            └─ case | in_11/adposition
    └─ punct | ._14/punctuation
Original: Mos denique imperatoris erat cunctis quiescentibus totum perreptare palatium .
root | Mos_0/adjective
    └─ advmod | denique_1/adverb
    └─ nmod | imperatoris_2/noun
    └─ cop | erat_3/auxiliary
    └─ advcl | quiescentibus_5/verb
        └─ det | cunctis_4/pronoun
    └─ csubj | perreptare_7/verb
        └─ obj | totum_6/pronoun
        └─ obj | palatium_8/noun
    └─ punct | ._9/punctuation
Original: Qui cum eodem die quadam , quo XII memorati loethoeo sese dederant , pervenisset , ligno modico , ut non incallidus , ostii pessulo proiecto ingrediendi sibi aditum praebuit .
root | pervenisset_13/verb
    └─ nsubj | Qui_0/pronoun
    └─ obl | die_3/noun
        └─ case | cum_1/adposition
        └─ det | eodem_2/determiner
        └─ det | quadam_4/determiner
        └─ acl:relcl | dederant_11/verb
            └─ punct | ,_5/punctuation
            └─ obl | quo_6/pronoun
            └─ csubj | memorati_8/verb
            └─ obl | loethoeo_9/noun
                └─ nummod | XII_7/numeral
            └─ expl:pass | sese_10/pronoun
        └─ punct | ,_12/punctuation
    └─ obl | ligno_15/noun
        └─ punct | ,_14/punctuation
        └─ amod | modico_16/adjective
    └─ advcl | praebuit_28/verb
        └─ advcl | incallidus_20/adjective
            └─ punct | ,_17/punctuation
            └─ mark | ut_18/subordinating_conjunction
            └─ advmod | non_19/particle
            └─ punct | ,_21/punctuation
        └─ advcl | proiecto_24/verb
            └─ nsubj:pass | pessulo_23/noun
                └─ nmod | ostii_22/noun
                └─ acl | ingrediendi_25/verb
        └─ xcomp | aditum_27/verb
            └─ obl:arg | sibi_26/pronoun
    └─ punct | ._29/punctuation
Original: Undecim vero dormientibus , ut ars artem falleret , duodecimus pervigil stertere ceu dormiens coeperat contractisque in fatiem brachiis totum , quod imperator faceret , diligentissime considerabat .
root | considerabat_26/verb
    └─ cc | vero_1/coordinating_conjunction
    └─ advcl | dormientibus_2/verb
        └─ nummod | Undecim_0/numeral
        └─ punct | ,_3/punctuation
    └─ advcl | falleret_7/verb
        └─ mark | ut_4/subordinating_conjunction
        └─ nsubj | ars_5/noun
        └─ obj | artem_6/noun
        └─ punct | ,_8/punctuation
        └─ conj | coeperat_14/verb
            └─ xcomp | stertere_11/verb
                └─ obj | pervigil_10/noun
                    └─ amod | duodecimus_9/adjective
            └─ mark | ceu_12/subordinating_conjunction
            └─ csubj | dormiens_13/verb
            └─ advcl | contractisque_15/verb
                └─ obl | fatiem_17/noun
                    └─ case | in_16/adposition
                    └─ nmod | brachiis_18/noun
                └─ obj | totum_19/pronoun
                    └─ acl:relcl | faceret_23/verb
                        └─ punct | ,_20/punctuation
                        └─ obj | quod_21/pronoun
                        └─ nsubj | imperator_22/noun
                        └─ punct | ,_24/punctuation
    └─ advmod | diligentissime_25/adverb
    └─ punct | ._27/punctuation
Original: Ingressus igitur imperator , dum obdormire cunctos perspiceret , aureorum numismatorum libram pectori uniuscuiusque apposuit ;
root | apposuit_14/verb
    └─ advcl | Ingressus_0/verb
    └─ advmod | igitur_1/adverb
    └─ nsubj | imperator_2/noun
        └─ punct | ,_3/punctuation
    └─ advcl | perspiceret_7/verb
        └─ mark | dum_4/subordinating_conjunction
        └─ xcomp | obdormire_5/verb
            └─ obj | cunctos_6/pronoun
        └─ punct | ,_8/punctuation
    └─ obj | libram_11/noun
        └─ nmod | aureorum_9/noun
        └─ nmod | numismatorum_10/noun
    └─ obl:arg | pectori_12/noun
        └─ nmod | uniuscuiusque_13/pronoun
    └─ punct | ;_15/punctuation
Original: moxque clam regressus , ostium , ut prius fuerat , clausit .
root | clausit_10/verb
    └─ advmod | moxque_0/subordinating_conjunction
    └─ advcl | regressus_2/verb
        └─ nsubj:pass | clam_1/noun
        └─ punct | ,_3/punctuation
    └─ obj | ostium_4/noun
        └─ punct | ,_5/punctuation
    └─ advcl | fuerat_8/verb
        └─ mark | ut_6/subordinating_conjunction
        └─ advmod | prius_7/adverb
        └─ punct | ,_9/punctuation
    └─ punct | ._11/punctuation
Original: Eo autem hoc egit , quatinus exitati et de lucro gratularentur ac , qualiter hoc accideret , non mediocriter mirarentur .
root | egit_3/verb
    └─ obl | Eo_0/pronoun
    └─ cc | autem_1/coordinating_conjunction
    └─ obj | hoc_2/pronoun
        └─ acl | gratularentur_10/verb
            └─ punct | ,_4/punctuation
            └─ mark | quatinus_5/subordinating_conjunction
            └─ csubj | exitati_6/verb
            └─ obl | lucro_9/noun
                └─ cc | et_7/coordinating_conjunction
                └─ case | de_8/adposition
    └─ conj | mirarentur_19/verb
        └─ cc | ac_11/coordinating_conjunction
            └─ punct | ,_12/punctuation
        └─ advcl | accideret_15/verb
            └─ advmod | qualiter_13/adverb
            └─ nsubj | hoc_14/pronoun
            └─ punct | ,_16/punctuation
        └─ advmod | mediocriter_18/adverb
            └─ advmod | non_17/particle
    └─ punct | ._20/punctuation
Original: Denique discedente imperatore , qui vigil solus extiterat , surrexit dormientiumque nummos aureos sibi adsumpsit atque reposuit ;
root | discedente_1/verb
    └─ nsubj | imperatore_2/noun
        └─ acl:relcl | extiterat_7/verb
            └─ punct | ,_3/punctuation
            └─ nsubj | qui_4/pronoun
            └─ nsubj | vigil_5/noun
                └─ advcl:pred | solus_6/adjective
            └─ conj | surrexit_9/verb
                └─ advmod | Denique_0/adverb
                └─ punct | ,_8/punctuation
                └─ conj | adsumpsit_14/verb
                    └─ obj | nummos_11/noun
                        └─ acl | dormientiumque_10/verb
                    └─ obj | aureos_12/noun
                    └─ obl:arg | sibi_13/pronoun
                    └─ conj | reposuit_16/verb
                        └─ cc | atque_15/coordinating_conjunction
                └─ punct | ;_17/punctuation
Original: postea vero quieti sese dedit .
root | dedit_4/verb
    └─ advmod | postea_0/adverb
    └─ cc | vero_1/coordinating_conjunction
    └─ obl:arg | quieti_2/noun
    └─ obj | sese_3/pronoun
    └─ punct | ._5/punctuation
Original: Imperator igitur pro hoc ludo sollicitus post-nonam horam XII hos , quos nominavimus , ad se venire praecepit eosque ita convenit Si forte vestrum quempiam somnii visio deterruit aut hilarem reddidit , ut in medium proferat , mea iubet auctoritas ;
root | praecepit_17/verb
    └─ nsubj | Imperator_0/noun
        └─ amod | sollicitus_5/adjective
            └─ obl | ludo_4/noun
                └─ case | pro_2/adposition
                └─ det | hoc_3/determiner
    └─ advmod | igitur_1/adverb
    └─ xcomp | venire_16/verb
        └─ obj | horam_7/noun
            └─ amod | post-nonam_6/adjective
            └─ nummod | XII_8/numeral
        └─ obj | hos_9/pronoun
            └─ acl:relcl | nominavimus_12/verb
                └─ punct | ,_10/punctuation
                └─ obj | quos_11/pronoun
            └─ punct | ,_13/punctuation
        └─ obl:arg | se_15/pronoun
            └─ case | ad_14/adposition
        └─ obj | eosque_18/pronoun
    └─ advcl | convenit_20/verb
        └─ advmod | ita_19/adverb
        └─ advcl | deterruit_27/verb
            └─ mark | Si_21/subordinating_conjunction
            └─ advmod:emph | forte_22/adverb
            └─ nsubj | visio_26/noun
                └─ det | vestrum_23/determiner
                └─ det | quempiam_24/determiner
                └─ nmod | somnii_25/noun
            └─ conj | reddidit_30/verb
                └─ cc | aut_28/coordinating_conjunction
                └─ obj | hilarem_29/noun
            └─ advcl | proferat_35/verb
                └─ punct | ,_31/punctuation
                └─ mark | ut_32/subordinating_conjunction
                └─ obl | medium_34/adjective
                    └─ case | in_33/adposition
                └─ conj | iubet_38/verb
                    └─ punct | ,_36/punctuation
                    └─ nsubj | auctoritas_39/noun
                        └─ det | mea_37/determiner
        └─ punct | ;_40/punctuation
Original: nec minus etiam , si quid novitatis expergefactus quisquam vidit , ut detegat , imperat .
root | minus_1/noun
    └─ cc | nec_0/coordinating_conjunction
    └─ advmod:emph | etiam_2/adverb
    └─ conj | vidit_9/verb
        └─ punct | ,_3/punctuation
        └─ mark | si_4/subordinating_conjunction
        └─ advcl | expergefactus_7/verb
            └─ obj | quid_5/pronoun
                └─ nmod | novitatis_6/noun
        └─ nsubj | quisquam_8/pronoun
        └─ advcl | detegat_12/verb
            └─ punct | ,_10/punctuation
            └─ mark | ut_11/subordinating_conjunction
            └─ conj | imperat_14/verb
                └─ punct | ,_13/punctuation
    └─ punct | ._15/punctuation
Original: Hi itaque , quemadmodum nihil viderant , nil se vidisse responderant .
root | responderant_10/verb
    └─ nsubj | Hi_0/pronoun
    └─ advmod | itaque_1/adverb
        └─ punct | ,_2/punctuation
    └─ advcl | viderant_5/verb
        └─ mark | quemadmodum_3/subordinating_conjunction
        └─ obj | nihil_4/pronoun
        └─ punct | ,_6/punctuation
    └─ xcomp | vidisse_9/verb
        └─ obj | nil_7/pronoun
        └─ obj | se_8/pronoun
    └─ punct | ._11/punctuation
Original: Magis autem super hoc admirati , conticuere intentique ora tenebant .
root | conticuere_6/verb
    └─ cc | autem_1/coordinating_conjunction
    └─ advcl | admirati_4/verb
        └─ advmod | Magis_0/adverb
        └─ obl | hoc_3/pronoun
            └─ case | super_2/adposition
        └─ punct | ,_5/punctuation
    └─ conj | tenebant_9/verb
        └─ nsubj | intentique_7/adjective
        └─ obj | ora_8/noun
    └─ punct | ._10/punctuation
Original: Sperans igitur imperator hos non rei inscitia , sed calliditate aliqua reticere , succensus est ut qui magis coepitque nonnulla terribilia reticentibus comminari .
root | succensus_13/verb
    └─ advcl | Sperans_0/verb
        └─ nsubj | imperator_2/noun
        └─ obj | hos_3/determiner
        └─ conj | reticere_11/verb
            └─ obl | inscitia_6/noun
                └─ advmod | non_4/particle
                └─ nmod | rei_5/noun
                └─ conj | calliditate_9/noun
                    └─ punct | ,_7/punctuation
                    └─ cc | sed_8/coordinating_conjunction
                    └─ det | aliqua_10/determiner
        └─ punct | ,_12/punctuation
    └─ advmod | igitur_1/adverb
    └─ aux:pass | est_14/auxiliary
    └─ csubj:pass | coepitque_18/verb
        └─ mark | ut_15/subordinating_conjunction
        └─ nsubj | qui_16/pronoun
        └─ advmod | magis_17/adverb
        └─ xcomp | comminari_22/verb
            └─ obj | terribilia_20/adjective
                └─ det | nonnulla_19/determiner
            └─ ccomp | reticentibus_21/verb
    └─ punct | ._23/punctuation
Original: Quod qui omnium conscius erat ut audivit , huiusmodi humillima et supplic voce imperatorem convenit φιλάνθρωπε βασιλεῦ , id est , humanissime imperator , hi quid viderint , nescio ;
root | convenit_14/verb
    └─ csubj | conscius_3/noun
        └─ nsubj | qui_1/pronoun
        └─ nmod | omnium_2/pronoun
        └─ cop | erat_4/auxiliary
        └─ advcl | audivit_6/verb
            └─ mark | ut_5/subordinating_conjunction
        └─ punct | ,_7/punctuation
    └─ obl | voce_12/noun
    └─ obj | imperatorem_13/noun
        └─ amod | humillima_9/adjective
            └─ advmod | huiusmodi_8/adverb
            └─ conj | supplic_11/adjective
                └─ cc | et_10/coordinating_conjunction
    └─ conj | βασιλεῦ_16/verb
        └─ obj | φιλάνθρωπε_15/punctuation
    └─ conj | nescio_28/verb
        └─ mark | Quod_0/subordinating_conjunction
        └─ nsubj | id_18/pronoun
            └─ punct | ,_17/punctuation
            └─ cop | est_19/auxiliary
            └─ nsubj | imperator_22/noun
                └─ punct | ,_20/punctuation
                └─ advmod | humanissime_21/adverb
        └─ nsubj | hi_24/pronoun
            └─ punct | ,_23/punctuation
            └─ punct | ,_27/punctuation
        └─ ccomp | viderint_26/verb
            └─ obj | quid_25/pronoun
        └─ punct | ;_29/punctuation
Original: ego tamen delectabile , atque utinam quod persaepe mihi contingeret , somnium vidi .
root | delectabile_2/adjective
    └─ nsubj | ego_0/pronoun
    └─ conj | utinam_5/verb
        └─ punct | ,_3/punctuation
        └─ cc | atque_4/coordinating_conjunction
        └─ acl:relcl | contingeret_9/verb
            └─ obj | quod_6/pronoun
            └─ advmod | persaepe_7/adverb
            └─ obl:arg | mihi_8/pronoun
    └─ conj | vidi_12/verb
        └─ advmod | tamen_1/adverb
        └─ punct | ,_10/punctuation
        └─ obj | somnium_11/noun
    └─ punct | ._13/punctuation
Original: Undecim his conservis meis hodie vere , sed non oportune dormientibus visus sum , quasi non dormiens , vigilare .
root | vere_5/verb
    └─ obl | Undecim_0/numeral
    └─ obl:arg | his_1/pronoun
    └─ obl:arg | conservis_2/noun
        └─ det | meis_3/determiner
    └─ advmod | hodie_4/adverb
    └─ conj | visus_11/verb
        └─ punct | ,_6/punctuation
        └─ cc | sed_7/coordinating_conjunction
        └─ advmod | oportune_9/adverb
            └─ advmod | non_8/particle
        └─ ccomp | dormientibus_10/verb
        └─ aux:pass | sum_12/auxiliary
        └─ conj | dormiens_16/verb
            └─ punct | ,_13/punctuation
            └─ advmod:emph | quasi_14/adverb
            └─ advmod | non_15/particle
        └─ advcl | vigilare_18/verb
            └─ punct | ,_17/punctuation
    └─ punct | ._19/punctuation
Original: Ecce autem magnitudo imperii tui quasi occulte ostium reserans clanculumque ingressa libram auri adposuit supra pectus omnium nostrum .
root | adposuit_13/verb
    └─ advmod | Ecce_0/adverb
    └─ cc | autem_1/coordinating_conjunction
    └─ nsubj | magnitudo_2/noun
        └─ nmod | imperii_3/noun
            └─ det | tui_4/determiner
        └─ acl | reserans_8/verb
            └─ advmod:emph | quasi_5/adverb
            └─ advmod | occulte_6/adverb
            └─ obj | ostium_7/noun
                └─ amod | clanculumque_9/adjective
    └─ advcl | ingressa_10/verb
    └─ obj | libram_11/noun
        └─ nmod | auri_12/noun
    └─ obl | pectus_15/noun
        └─ case | supra_14/adposition
        └─ nmod | omnium_16/pronoun
        └─ det | nostrum_17/determiner
    └─ punct | ._18/punctuation
Original: Cumque imperium tuum quasi repedare sotiosque hac in visione cernerem dormitare , continuo ceu laetus exurgens undecim dormientium aureorum numismatorum libras tuli meoque in marsupio , in quo una erat , apposui , quatinus ob trangressionem decalogi ne solum essent XI , verum ob memoriam apostolorum mea una adhibita essent et ipsae XII .
root | cernerem_9/verb
    └─ mark | Cumque_0/subordinating_conjunction
    └─ obj | imperium_1/noun
        └─ det | tuum_2/determiner
    └─ mark | quasi_3/subordinating_conjunction
    └─ xcomp | repedare_4/verb
        └─ obj | sotiosque_5/noun
        └─ obl | visione_8/noun
            └─ det | hac_6/determiner
            └─ case | in_7/adposition
    └─ xcomp | dormitare_10/verb
    └─ conj | meoque_22/verb
        └─ obl | continuo_12/adjective
            └─ punct | ,_11/punctuation
        └─ advcl | laetus_14/verb
            └─ conj | exurgens_15/verb
        └─ advcl | tuli_21/verb
            └─ mark | ceu_13/subordinating_conjunction
            └─ obj | libras_20/noun
                └─ nmod | aureorum_18/noun
                    └─ acl | dormientium_17/verb
                        └─ nummod | undecim_16/numeral
                    └─ nmod | numismatorum_19/noun
        └─ obl | marsupio_24/noun
            └─ case | in_23/adposition
            └─ acl:relcl | una_28/numeral
                └─ punct | ,_25/punctuation
                └─ obl | quo_27/pronoun
                    └─ case | in_26/adposition
                └─ cop | erat_29/auxiliary
            └─ acl:relcl | apposui_31/verb
                └─ punct | ,_30/punctuation
                └─ obl | trangressionem_35/noun
                    └─ punct | ,_32/punctuation
                    └─ mark | quatinus_33/subordinating_conjunction
                    └─ case | ob_34/adposition
                    └─ nmod | decalogi_36/noun
                └─ advcl | essent_39/auxiliary
                    └─ mark | ne_37/subordinating_conjunction
                    └─ obl | XI_40/numeral
                        └─ advmod | solum_38/adverb
                └─ advcl | adhibita_48/verb
                    └─ punct | ,_41/punctuation
                    └─ mark | verum_42/coordinating_conjunction
                    └─ obl | memoriam_44/noun
                        └─ case | ob_43/adposition
                        └─ nmod | apostolorum_45/noun
                    └─ nsubj:pass | una_47/numeral
                        └─ det | mea_46/determiner
                    └─ aux:pass | essent_49/auxiliary
                    └─ conj | ipsae_51/pronoun
                        └─ cc | et_50/coordinating_conjunction
                        └─ orphan | XII_52/numeral
                └─ punct | ._53/punctuation
Original: Visio haec , imperator auguste , bonum sit , usque modo me non deterruit , sed hilarem reddidit .
root | deterruit_13/verb
    └─ nsubj | Visio_0/noun
        └─ det | haec_1/determiner
        └─ conj | auguste_4/verb
            └─ punct | ,_2/punctuation
            └─ nsubj | imperator_3/noun
            └─ conj | bonum_6/noun
                └─ punct | ,_5/punctuation
                └─ cop | sit_7/auxiliary
        └─ punct | ,_8/punctuation
    └─ obl | modo_10/noun
        └─ case | usque_9/adposition
    └─ obj | me_11/pronoun
    └─ advmod | non_12/particle
    └─ conj | reddidit_17/verb
        └─ punct | ,_14/punctuation
        └─ cc | sed_15/coordinating_conjunction
        └─ obj | hilarem_16/noun
    └─ punct | ._18/punctuation
Original: utinam interpretatio alia imperio tuo non place at .
root | at_7/verb
    └─ advmod | utinam_0/adverb
    └─ nsubj | interpretatio_1/noun
        └─ det | alia_2/determiner
    └─ obl | imperio_3/noun
        └─ det | tuo_4/determiner
    └─ obl | place_6/noun
        └─ advmod | non_5/particle
    └─ punct | ._8/punctuation
Original: Nam et me μάντιν κε ὀνειροπόλον ( mantin ke oniropolon ) ;
root | ὀνειροπόλον_5/verb
    └─ advmod | Nam_0/adverb
    └─ cc | et_1/coordinating_conjunction
    └─ obj | me_2/pronoun
    └─ advmod | μάντιν_3/punctuation
    └─ obl:arg | κε_4/noun
    └─ conj | mantin_7/noun
        └─ punct | (_6/punctuation
        └─ orphan | oniropolon_9/noun
            └─ nummod | ke_8/numeral
        └─ punct | )_10/punctuation
    └─ punct | ;_11/punctuation
Original: id est divinum et somnii venditorem , esse liquido patet .
root | patet_9/verb
    └─ csubj | divinum_2/adjective
        └─ nsubj | id_0/pronoun
        └─ cop | est_1/auxiliary
        └─ conj | venditorem_5/noun
            └─ cc | et_3/coordinating_conjunction
            └─ nmod | somnii_4/noun
        └─ punct | ,_6/punctuation
    └─ xcomp | esse_7/auxiliary
    └─ obl | liquido_8/adjective
    └─ punct | ._10/punctuation
Original: His auditis magno est imperator cachinno inflatus ;
root | inflatus_6/verb
    └─ advcl | auditis_1/verb
        └─ nsubj:pass | His_0/pronoun
        └─ amod | magno_2/adjective
    └─ cop | est_3/auxiliary
    └─ nsubj:pass | imperator_4/noun
    └─ obl:arg | cachinno_5/noun
    └─ punct | ;_7/punctuation
Original: verum prudentiam huius atque sollicitudinem plus admiratus protinus infit Antehac σε οὖτε μαντιν οὖτε ὀνειροπόλον se ute mantin ute oniropolon , te neque divinum neque somnii venditorem esse audivi .
root | infit_8/verb
    └─ obl | prudentiam_1/noun
        └─ case | verum_0/adposition
        └─ nmod | huius_2/pronoun
        └─ conj | sollicitudinem_4/noun
            └─ cc | atque_3/coordinating_conjunction
    └─ advcl | admiratus_6/verb
        └─ advmod | plus_5/adverb
    └─ advmod | protinus_7/adverb
    └─ obl:arg | Antehac_9/noun
    └─ advmod | σε_10/adverb
        └─ nummod | οὖτε_11/numeral
    └─ conj | οὖτε_13/verb
        └─ punct | μαντιν_12/punctuation
        └─ obl | se_15/pronoun
            └─ case | ὀνειροπόλον_14/adposition
        └─ obl | ute_16/noun
            └─ nmod | mantin_17/noun
        └─ obl | oniropolon_19/noun
            └─ nmod | ute_18/noun
        └─ conj | audivi_28/verb
            └─ punct | ,_20/punctuation
            └─ obj | te_21/pronoun
            └─ ccomp | venditorem_26/noun
                └─ amod | divinum_23/adjective
                    └─ cc | neque_22/coordinating_conjunction
                    └─ conj | somnii_25/noun
                        └─ cc | neque_24/coordinating_conjunction
                └─ cop | esse_27/auxiliary
    └─ punct | ._29/punctuation
Original: Hanc vero rem nunc ita aperte dixti , ut nihil circuitionis usus esses .
root | dixti_6/verb
    └─ cc | vero_1/coordinating_conjunction
    └─ obj | rem_2/noun
        └─ det | Hanc_0/determiner
    └─ advmod | nunc_3/adverb
    └─ advmod | aperte_5/adverb
        └─ advmod | ita_4/adverb
    └─ advcl | usus_11/noun
        └─ punct | ,_7/punctuation
        └─ mark | ut_8/subordinating_conjunction
        └─ nsubj | nihil_9/pronoun
            └─ nmod | circuitionis_10/noun
        └─ cop | esses_12/auxiliary
    └─ punct | ._13/punctuation
Original: Sed quia vigilandi facultatem sive auspicandi scientiam habere non posses , nisi divino tibi esset munere datum , seu verum sit , ut speramus , immo credimus , seu falsum , Lukianos , id est sicut Lucianus de quodam dicit , quod dormiens multa reppererit atque a gallo exitatus nihil invenerit , tu tamen quicquid videris , quicquid senseris , quicquid etiam inveneris , tuum sit .
root | est_34/verb
    └─ advcl | posses_9/verb
        └─ cc | Sed_0/coordinating_conjunction
        └─ mark | quia_1/subordinating_conjunction
        └─ xcomp | habere_7/verb
            └─ obj | facultatem_3/noun
                └─ acl | vigilandi_2/verb
                └─ acl | auspicandi_5/verb
                    └─ cc | sive_4/coordinating_conjunction
            └─ obj | scientiam_6/noun
        └─ advmod | non_8/particle
        └─ advcl | datum_16/verb
            └─ punct | ,_10/punctuation
            └─ mark | nisi_11/subordinating_conjunction
            └─ obl:arg | tibi_13/pronoun
            └─ aux:pass | esset_14/auxiliary
            └─ obl | munere_15/noun
                └─ amod | divino_12/adjective
            └─ conj | verum_19/adjective
                └─ punct | ,_17/punctuation
                └─ cc | seu_18/coordinating_conjunction
                └─ cop | sit_20/auxiliary
                └─ advcl | speramus_23/verb
                    └─ punct | ,_21/punctuation
                    └─ mark | ut_22/subordinating_conjunction
                └─ conj | credimus_26/verb
                    └─ punct | ,_24/punctuation
                    └─ advmod | immo_25/adverb
                    └─ conj | falsum_29/adjective
                        └─ punct | ,_27/punctuation
                        └─ cc | seu_28/coordinating_conjunction
                    └─ obj | Lukianos_31/noun
                        └─ punct | ,_30/punctuation
    └─ punct | ,_32/punctuation
    └─ nsubj | id_33/pronoun
    └─ advcl | dicit_39/verb
        └─ mark | sicut_35/subordinating_conjunction
        └─ nsubj | Lucianus_36/proper_noun
        └─ obl | quodam_38/pronoun
            └─ case | de_37/adposition
        └─ ccomp | reppererit_44/verb
            └─ punct | ,_40/punctuation
            └─ mark | quod_41/subordinating_conjunction
            └─ csubj | dormiens_42/verb
            └─ obj | multa_43/adjective
            └─ conj | invenerit_50/verb
                └─ cc | atque_45/coordinating_conjunction
                └─ advcl | exitatus_48/verb
                    └─ obl:arg | gallo_47/noun
                        └─ case | a_46/adposition
                └─ obj | nihil_49/pronoun
    └─ conj | tuum_64/determiner
        └─ nsubj | tu_52/pronoun
        └─ advmod | tamen_53/adverb
        └─ csubj | videris_55/verb
            └─ punct | ,_51/punctuation
            └─ obj | quicquid_54/pronoun
            └─ ccomp | senseris_58/verb
                └─ punct | ,_56/punctuation
                └─ obj | quicquid_57/pronoun
        └─ csubj | inveneris_62/verb
            └─ punct | ,_59/punctuation
            └─ obj | quicquid_60/pronoun
                └─ advmod:emph | etiam_61/adverb
            └─ punct | ,_63/punctuation
        └─ cop | sit_65/auxiliary
    └─ punct | ._66/punctuation
Original: His auditis , quanta ceteri sint confusione repleti , quantoque hie sit gaudio plenus , eorum quisque in se personas suscipiens animadvertere poterit .
root | poterit_22/verb
    └─ advcl | auditis_1/verb
        └─ nsubj:pass | His_0/pronoun
        └─ punct | ,_2/punctuation
    └─ advcl | repleti_7/verb
        └─ nsubj:pass | quanta_3/pronoun
            └─ det | ceteri_4/pronoun
        └─ aux:pass | sint_5/auxiliary
        └─ obl | confusione_6/noun
        └─ conj | plenus_13/adjective
            └─ punct | ,_8/punctuation
            └─ advmod:emph | quantoque_9/subordinating_conjunction
            └─ nsubj | hie_10/noun
            └─ cop | sit_11/auxiliary
            └─ obl | gaudio_12/noun
        └─ punct | ,_14/punctuation
    └─ nsubj | quisque_16/pronoun
        └─ nmod | eorum_15/pronoun
        └─ acl | suscipiens_20/verb
            └─ obl | se_18/pronoun
                └─ case | in_17/adposition
    └─ xcomp | animadvertere_21/verb
        └─ obj | personas_19/noun
    └─ punct | ._23/punctuation
"""

def process_line(line):
    indent = len(line) - len(line.lstrip())
    parts = line.split('|')
    if len(parts) == 2:
        word = parts[1].split('_')[0].strip()
        return ' ' * indent + word
    return line

def remove_punct_and_numbers(text):
    lines = text.split('\n')
    processed_lines = [process_line(line) for line in lines]
    return '\n'.join(processed_lines)

output_text = remove_punct_and_numbers(input_text)
print(output_text)
pyperclip.copy(output_text)
# Out:
# Original: Alium , quem ipse egit , ludum silentio tegi absurdum esse diiudico .
# tegi
#     ludum
#     silentio
#     diiudico
#         Alium
#             egit
#                 ,
#                 quem
#                 ipse
#             ,
#             .
#         absurdum
#         esse
# Original: Constantinopolitanum palatium ob imperatoris salutem multorum praesidiis militum custoditur .
# custoditur
#     palatium
#         Constantinopolitanum
#     salutem
#         ob
#         imperatoris
#     praesidiis
#         multorum
#         militum
#     .
# Original: Custodientibus vero victus censusque cottidanus non parvus inpenditur .
# inpenditur
#     Custodientibus
#         victus
#     vero
#     cottidanus
#         censusque
#     parvus
#         non
#     .
# Original: Contigit itaque XII post corporis refectionem in ipso diei fervore una in domo quiescere .
# Contigit
#     itaque
#     XII
#     quiescere
#         refectionem
#             post
# ...

# %%
# !pip install pyperclip
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11124 sha256=27577e14552fd87afe738901b3b1380c5b2a4e014a84144f596b9ca976ac5fe4
#   Stored in directory: /root/.cache/pip/wheels/0c/09/9e/49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
# Successfully built pyperclip
# ...

# %%
import pyperclip

def format_output(text):
    lines = text.split('\n')
    formatted_lines = []
    prev_indent_level = -1
    current_line = ''

    for line in lines:
        line = line.replace(',', '')
        stripped_line = line.lstrip()
        indent_level = len(line) - len(stripped_line)

        if indent_level == prev_indent_level:
            current_line += ' ' + stripped_line
        else:
            if prev_indent_level != -1:
                formatted_lines.append(current_line)
            current_line = ' ' * indent_level + stripped_line
            prev_indent_level = indent_level

    formatted_lines.append(current_line)
    return '\n'.join(formatted_lines)

input_text = '''
Original: Alium , quem ipse egit , ludum silentio tegi absurdum esse diiudico .
tegi
    ludum
    silentio
    diiudico
        Alium
            egit
                ,
                quem
                ipse
            ,
            .
        absurdum
        esse
Original: Constantinopolitanum palatium ob imperatoris salutem multorum praesidiis militum custoditur .
custoditur
    palatium
        Constantinopolitanum
    salutem
        ob
        imperatoris
    praesidiis
        multorum
        militum
    .
Original: Custodientibus vero victus censusque cottidanus non parvus inpenditur .
inpenditur
    Custodientibus
        victus
    vero
    cottidanus
        censusque
    parvus
        non
    .
Original: Contigit itaque XII post corporis refectionem in ipso diei fervore una in domo quiescere .
Contigit
    itaque
    XII
    quiescere
        refectionem
            post
            corporis
        diei
            in
            ipso
        fervore
            una
        domo
            in
    .
Original: Mos denique imperatoris erat cunctis quiescentibus totum perreptare palatium .
Mos
    denique
    imperatoris
    erat
    quiescentibus
        cunctis
    perreptare
        totum
        palatium
    .
Original: Qui cum eodem die quadam , quo XII memorati loethoeo sese dederant , pervenisset , ligno modico , ut non incallidus , ostii pessulo proiecto ingrediendi sibi aditum praebuit .
pervenisset
    Qui
    die
        cum
        eodem
        quadam
        dederant
            ,
            quo
            memorati
            loethoeo
                XII
            sese
        ,
    ligno
        ,
        modico
    praebuit
        incallidus
            ,
            ut
            non
            ,
        proiecto
            pessulo
                ostii
                ingrediendi
        aditum
            sibi
    .
Original: Undecim vero dormientibus , ut ars artem falleret , duodecimus pervigil stertere ceu dormiens coeperat contractisque in fatiem brachiis totum , quod imperator faceret , diligentissime considerabat .
considerabat
    vero
    dormientibus
        Undecim
        ,
    falleret
        ut
        ars
        artem
        ,
        coeperat
            stertere
                pervigil
                    duodecimus
            ceu
            dormiens
            contractisque
                fatiem
                    in
                    brachiis
                totum
                    faceret
                        ,
                        quod
                        imperator
                        ,
    diligentissime
    .
Original: Ingressus igitur imperator , dum obdormire cunctos perspiceret , aureorum numismatorum libram pectori uniuscuiusque apposuit ;
apposuit
    Ingressus
    igitur
    imperator
        ,
    perspiceret
        dum
        obdormire
            cunctos
        ,
    libram
        aureorum
        numismatorum
    pectori
        uniuscuiusque
    ;
Original: moxque clam regressus , ostium , ut prius fuerat , clausit .
clausit
    moxque
    regressus
        clam
        ,
    ostium
        ,
    fuerat
        ut
        prius
        ,
    .
Original: Eo autem hoc egit , quatinus exitati et de lucro gratularentur ac , qualiter hoc accideret , non mediocriter mirarentur .
egit
    Eo
    autem
    hoc
        gratularentur
            ,
            quatinus
            exitati
            lucro
                et
                de
    mirarentur
        ac
            ,
        accideret
            qualiter
            hoc
            ,
        mediocriter
            non
    .
Original: Denique discedente imperatore , qui vigil solus extiterat , surrexit dormientiumque nummos aureos sibi adsumpsit atque reposuit ;
discedente
    imperatore
        extiterat
            ,
            qui
            vigil
                solus
            surrexit
                Denique
                ,
                adsumpsit
                    nummos
                        dormientiumque
                    aureos
                    sibi
                    reposuit
                        atque
                ;
Original: postea vero quieti sese dedit .
dedit
    postea
    vero
    quieti
    sese
    .
Original: Imperator igitur pro hoc ludo sollicitus post-nonam horam XII hos , quos nominavimus , ad se venire praecepit eosque ita convenit Si forte vestrum quempiam somnii visio deterruit aut hilarem reddidit , ut in medium proferat , mea iubet auctoritas ;
praecepit
    Imperator
        sollicitus
            ludo
                pro
                hoc
    igitur
    venire
        horam
            post-nonam
            XII
        hos
            nominavimus
                ,
                quos
            ,
        se
            ad
        eosque
    convenit
        ita
        deterruit
            Si
            forte
            visio
                vestrum
                quempiam
                somnii
            reddidit
                aut
                hilarem
            proferat
                ,
                ut
                medium
                    in
                iubet
                    ,
                    auctoritas
                        mea
        ;
Original: nec minus etiam , si quid novitatis expergefactus quisquam vidit , ut detegat , imperat .
minus
    nec
    etiam
    vidit
        ,
        si
        expergefactus
            quid
                novitatis
        quisquam
        detegat
            ,
            ut
            imperat
                ,
    .
Original: Hi itaque , quemadmodum nihil viderant , nil se vidisse responderant .
responderant
    Hi
    itaque
        ,
    viderant
        quemadmodum
        nihil
        ,
    vidisse
        nil
        se
    .
Original: Magis autem super hoc admirati , conticuere intentique ora tenebant .
conticuere
    autem
    admirati
        Magis
        hoc
            super
        ,
    tenebant
        intentique
        ora
    .
Original: Sperans igitur imperator hos non rei inscitia , sed calliditate aliqua reticere , succensus est ut qui magis coepitque nonnulla terribilia reticentibus comminari .
succensus
    Sperans
        imperator
        hos
        reticere
            inscitia
                non
                rei
                calliditate
                    ,
                    sed
                    aliqua
        ,
    igitur
    est
    coepitque
        ut
        qui
        magis
        comminari
            terribilia
                nonnulla
            reticentibus
    .
Original: Quod qui omnium conscius erat ut audivit , huiusmodi humillima et supplic voce imperatorem convenit ╧å╬╣╬╗╬¼╬╜╬╕╧ü╧ë╧Ç╬╡ ╬▓╬▒╧â╬╣╬╗╬╡ß┐ª , id est , humanissime imperator , hi quid viderint , nescio ;
convenit
    conscius
        qui
        omnium
        erat
        audivit
            ut
        ,
    voce
    imperatorem
        humillima
            huiusmodi
            supplic
                et
    ╬▓╬▒╧â╬╣╬╗╬╡ß┐ª
        ╧å╬╣╬╗╬¼╬╜╬╕╧ü╧ë╧Ç╬╡
    nescio
        Quod
        id
            ,
            est
            imperator
                ,
                humanissime
        hi
            ,
            ,
        viderint
            quid
        ;
Original: ego tamen delectabile , atque utinam quod persaepe mihi contingeret , somnium vidi .
delectabile
    ego
    utinam
        ,
        atque
        contingeret
            quod
            persaepe
            mihi
    vidi
        tamen
        ,
        somnium
    .
Original: Undecim his conservis meis hodie vere , sed non oportune dormientibus visus sum , quasi non dormiens , vigilare .
vere
    Undecim
    his
    conservis
        meis
    hodie
    visus
        ,
        sed
        oportune
            non
        dormientibus
        sum
        dormiens
            ,
            quasi
            non
        vigilare
            ,
    .
Original: Ecce autem magnitudo imperii tui quasi occulte ostium reserans clanculumque ingressa libram auri adposuit supra pectus omnium nostrum .
adposuit
    Ecce
    autem
    magnitudo
        imperii
            tui
        reserans
            quasi
            occulte
            ostium
                clanculumque
    ingressa
    libram
        auri
    pectus
        supra
        omnium
        nostrum
    .
Original: Cumque imperium tuum quasi repedare sotiosque hac in visione cernerem dormitare , continuo ceu laetus exurgens undecim dormientium aureorum numismatorum libras tuli meoque in marsupio , in quo una erat , apposui , quatinus ob trangressionem decalogi ne solum essent XI , verum ob memoriam apostolorum mea una adhibita essent et ipsae XII .
cernerem
    Cumque
    imperium
        tuum
    quasi
    repedare
        sotiosque
        visione
            hac
            in
    dormitare
    meoque
        continuo
            ,
        laetus
            exurgens
        tuli
            ceu
            libras
                aureorum
                    dormientium
                        undecim
                    numismatorum
        marsupio
            in
            una
                ,
                quo
                    in
                erat
            apposui
                ,
                trangressionem
                    ,
                    quatinus
                    ob
                    decalogi
                essent
                    ne
                    XI
                        solum
                adhibita
                    ,
                    verum
                    memoriam
                        ob
                        apostolorum
                    una
                        mea
                    essent
                    ipsae
                        et
                        XII
                .
Original: Visio haec , imperator auguste , bonum sit , usque modo me non deterruit , sed hilarem reddidit .
deterruit
    Visio
        haec
        auguste
            ,
            imperator
            bonum
                ,
                sit
        ,
    modo
        usque
    me
    non
    reddidit
        ,
        sed
        hilarem
    .
Original: utinam interpretatio alia imperio tuo non place at .
at
    utinam
    interpretatio
        alia
    imperio
        tuo
    place
        non
    .
Original: Nam et me ╬╝╬¼╬╜╧ä╬╣╬╜ ╬║╬╡ ß╜Ç╬╜╬╡╬╣╧ü╬┐╧Ç╧î╬╗╬┐╬╜ ( mantin ke oniropolon ) ;
ß╜Ç╬╜╬╡╬╣╧ü╬┐╧Ç╧î╬╗╬┐╬╜
    Nam
    et
    me
    ╬╝╬¼╬╜╧ä╬╣╬╜
    ╬║╬╡
    mantin
        (
        oniropolon
            ke
        )
    ;
Original: id est divinum et somnii venditorem , esse liquido patet .
patet
    divinum
        id
        est
        venditorem
            et
            somnii
        ,
    esse
    liquido
    .
Original: His auditis magno est imperator cachinno inflatus ;
inflatus
    auditis
        His
        magno
    est
    imperator
    cachinno
    ;
Original: verum prudentiam huius atque sollicitudinem plus admiratus protinus infit Antehac ╧â╬╡ ╬┐ß╜û╧ä╬╡ ╬╝╬▒╬╜╧ä╬╣╬╜ ╬┐ß╜û╧ä╬╡ ß╜Ç╬╜╬╡╬╣╧ü╬┐╧Ç╧î╬╗╬┐╬╜ se ute mantin ute oniropolon , te neque divinum neque somnii venditorem esse audivi .
infit
    prudentiam
        verum
        huius
        sollicitudinem
            atque
    admiratus
        plus
    protinus
    Antehac
    ╧â╬╡
        ╬┐ß╜û╧ä╬╡
    ╬┐ß╜û╧ä╬╡
        ╬╝╬▒╬╜╧ä╬╣╬╜
        se
            ß╜Ç╬╜╬╡╬╣╧ü╬┐╧Ç╧î╬╗╬┐╬╜
        ute
            mantin
        oniropolon
            ute
        audivi
            ,
            te
            venditorem
                divinum
                    neque
                    somnii
                        neque
                esse
    .
Original: Hanc vero rem nunc ita aperte dixti , ut nihil circuitionis usus esses .
dixti
    vero
    rem
        Hanc
    nunc
    aperte
        ita
    usus
        ,
        ut
        nihil
            circuitionis
        esses
    .
Original: Sed quia vigilandi facultatem sive auspicandi scientiam habere non posses , nisi divino tibi esset munere datum , seu verum sit , ut speramus , immo credimus , seu falsum , Lukianos , id est sicut Lucianus de quodam dicit , quod dormiens multa reppererit atque a gallo exitatus nihil invenerit , tu tamen quicquid videris , quicquid senseris , quicquid etiam inveneris , tuum sit .
est
    posses
        Sed
        quia
        habere
            facultatem
                vigilandi
                auspicandi
                    sive
            scientiam
        non
        datum
            ,
            nisi
            tibi
            esset
            munere
                divino
            verum
                ,
                seu
                sit
                speramus
                    ,
                    ut
                credimus
                    ,
                    immo
                    falsum
                        ,
                        seu
                    Lukianos
                        ,
    ,
    id
    dicit
        sicut
        Lucianus
        quodam
            de
        reppererit
            ,
            quod
            dormiens
            multa
            invenerit
                atque
                exitatus
                    gallo
                        a
                nihil
    tuum
        tu
        tamen
        videris
            ,
            quicquid
            senseris
                ,
                quicquid
        inveneris
            ,
            quicquid
                etiam
            ,
        sit
    .
Original: His auditis , quanta ceteri sint confusione repleti , quantoque hie sit gaudio plenus , eorum quisque in se personas suscipiens animadvertere poterit .
poterit
    auditis
        His
        ,
    repleti
        quanta
            ceteri
        sint
        confusione
        plenus
            ,
            quantoque
            hie
            sit
            gaudio
        ,
    quisque
        eorum
        suscipiens
            se
                in
    animadvertere
        personas
    .
'''

formatted_text = format_output(input_text)
print(formatted_text)
pyperclip.copy(formatted_text)
# Out:
#  Original: Alium  quem ipse egit  ludum silentio tegi absurdum esse diiudico . tegi
#     ludum silentio diiudico
#         Alium
#             egit
#                  quem ipse
#              .
#         absurdum esse
# Original: Constantinopolitanum palatium ob imperatoris salutem multorum praesidiis militum custoditur . custoditur
#     palatium
#         Constantinopolitanum
#     salutem
#         ob imperatoris
#     praesidiis
#         multorum militum
#     .
# Original: Custodientibus vero victus censusque cottidanus non parvus inpenditur . inpenditur
#     Custodientibus
#         victus
#     vero cottidanus
#         censusque
#     parvus
#         non
#     .
# Original: Contigit itaque XII post corporis refectionem in ipso diei fervore una in domo quiescere . Contigit
#     itaque XII quiescere
#         refectionem
#             post corporis
#         diei
#             in ipso
#         fervore
#             una
#         domo
#             in
#     .
# ...
